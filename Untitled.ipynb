# %%
import matplotlib

# %%
matplotlib.pyplot.plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 matplotlib.pyplot.plot
#
# File ~\miniforge3\envs\enma165\Lib\site-packages\matplotlib\_api\__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
