# %% [markdown]
# # Looping Over Datasets

# %%
for filename in ["./data/gapminder_gdp_asia.csv", "./data/gapminder_gdp_africa.csv"]:
    print(filename)
# Out:
# ./data/gapminder_gdp_asia.csv
# ./data/gapminder_gdp_africa.csv

# %%
for filename in ["./data/gapminder_gdp_asia.csv", "./data/gapminder_gdp_africa.csv"]:
    file = open(filename)
    print(file.readline())
    file.close()
# Out:
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
#
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007

# %%
import glob

# %%
glob.glob("./data/*")
# Out:
# ['./data/gapminder_gdp_americas.csv',
#  './data/gapminder_gdp_europe.csv',
#  './data/gapminder_all.csv',
#  './data/gapminder_gdp_oceania.csv',
#  './data/gapminder_gdp_africa.csv',
#  './data/gapminder_gdp_asia.csv']

# %%
for filename in glob.glob("./data/*"):
    file = open(filename)
    print(file.readline())
    file.close()
# Out:
# continent,country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
#
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
#
# "continent","country","gdpPercap_1952","gdpPercap_1957","gdpPercap_1962","gdpPercap_1967","gdpPercap_1972","gdpPercap_1977","gdpPercap_1982","gdpPercap_1987","gdpPercap_1992","gdpPercap_1997","gdpPercap_2002","gdpPercap_2007","lifeExp_1952","lifeExp_1957","lifeExp_1962","lifeExp_1967","lifeExp_1972","lifeExp_1977","lifeExp_1982","lifeExp_1987","lifeExp_1992","lifeExp_1997","lifeExp_2002","lifeExp_2007","pop_1952","pop_1957","pop_1962","pop_1967","pop_1972","pop_1977","pop_1982","pop_1987","pop_1992","pop_1997","pop_2002","pop_2007"
#
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
#
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
#
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007

# %%
glob.glob("./data/gapminder_gdp_a*")
# Out:
# ['./data/gapminder_gdp_americas.csv',
#  './data/gapminder_gdp_africa.csv',
#  './data/gapminder_gdp_asia.csv']

# %%
glob.glob("./data/*.csv")
# Out:
# ['./data/gapminder_gdp_americas.csv',
#  './data/gapminder_gdp_europe.csv',
#  './data/gapminder_all.csv',
#  './data/gapminder_gdp_oceania.csv',
#  './data/gapminder_gdp_africa.csv',
#  './data/gapminder_gdp_asia.csv']

# %%
glob.glob("./data/*gdp*")
# Out:
# ['./data/gapminder_gdp_americas.csv',
#  './data/gapminder_gdp_europe.csv',
#  './data/gapminder_gdp_oceania.csv',
#  './data/gapminder_gdp_africa.csv',
#  './data/gapminder_gdp_asia.csv']

# %%
with open('./data/gapminder_gdp_oceania.csv') as file:
    header = file.readline()
    table = []
    for line in file:
        table.append(line)

# %% [markdown]
# use acculmulator pattern to collect items in column 3

# %% [markdown]
# combine above steps to calculate average

# %% [markdown]
# ## Turn it into a Function

# %%
def average_for_a_column(col,data):
    collect = []
    for row in data:
        collect.append(float(row[col]))
    return sum(collect)/len(collect)

# %%
print(average_for_a_column(col = 1,data=table))
# Out:
# 10298.08565

# %%
average_for_a_column(1,table)
# Out:
# 10298.08565

# %%
# Function to read CSV file
def read_csv_file(filepath):
    with open(filepath, 'r') as f:
        lines = f.readlines()
    
    # Clean and split each line
    lines = [line.strip().split(',') for line in lines]
    headers = lines[0]   # first row (column names)
    data = lines[1:]     # rest of the rows
    return headers, data

# %%
headers, data=read_csv_file("data/gapminder_gdp_americas.csv")

# %%
print(average_for_a_column(data=data, col = 4))
# Out:
# 4901.5418704

# %%
for row in data:
    print(row)
# Out:
# ['Americas', 'Argentina', '5911.315053', '6856.856212', '7133.166023', '8052.953021', '9443.038526', '10079.02674', '8997.897412', '9139.671389', '9308.41871', '10967.28195', '8797.640716', '12779.37964']
# ['Americas', 'Bolivia', '2677.326347', '2127.686326', '2180.972546', '2586.886053', '2980.331339', '3548.097832', '3156.510452', '2753.69149', '2961.699694', '3326.143191', '3413.26269', '3822.137084']
# ['Americas', 'Brazil', '2108.944355', '2487.365989', '3336.585802', '3429.864357', '4985.711467', '6660.118654', '7030.835878', '7807.095818', '6950.283021', '7957.980824', '8131.212843', '9065.800825']
# ['Americas', 'Canada', '11367.16112', '12489.95006', '13462.48555', '16076.58803', '18970.57086', '22090.88306', '22898.79214', '26626.51503', '26342.88426', '28954.92589', '33328.96507', '36319.23501']
# ['Americas', 'Chile', '3939.978789', '4315.622723', '4519.094331', '5106.654313', '5494.024437', '4756.763836', '5095.665738', '5547.063754', '7596.125964', '10118.05318', '10778.78385', '13171.63885']
# ['Americas', 'Colombia', '2144.115096', '2323.805581', '2492.351109', '2678.729839', '3264.660041', '3815.80787', '4397.575659', '4903.2191', '5444.648617', '6117.361746', '5755.259962', '7006.580419']
# ['Americas', 'Costa Rica', '2627.009471', '2990.010802', '3460.937025', '4161.727834', '5118.146939', '5926.876967', '5262.734751', '5629.915318', '6160.416317', '6677.045314', '7723.447195', '9645.06142']
# ['Americas', 'Cuba', '5586.53878', '6092.174359', '5180.75591', '5690.268015', '5305.445256', '6380.494966', '7316.918107', '7532.924763', '5592.843963', '5431.990415', '6340.646683', '8948.102923']
# ['Americas', 'Dominican Republic', '1397.717137', '1544.402995', '1662.137359', '1653.723003', '2189.874499', '2681.9889', '2861.092386', '2899.842175', '3044.214214', '3614.101285', '4563.808154', '6025.374752']
# ['Americas', 'Ecuador', '3522.110717', '3780.546651', '4086.114078', '4579.074215', '5280.99471', '6679.62326', '7213.791267', '6481.776993', '7103.702595', '7429.455877', '5773.044512', '6873.262326']
# ['Americas', 'El Salvador', '3048.3029', '3421.523218', '3776.803627', '4358.595393', '4520.246008', '5138.922374', '4098.344175', '4140.442097', '4444.2317', '5154.825496', '5351.568666', '5728.353514']
